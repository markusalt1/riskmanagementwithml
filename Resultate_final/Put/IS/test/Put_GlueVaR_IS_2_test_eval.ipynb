# %%
import joblib
import os
import numpy as np
import matplotlib.pyplot as plt

#folder containing saved results from Put_GlueVaR_IS_2_test.ipynb
filepath = ".../Resultate_final/Put/IS/test/Put_GlueVaR_IS_2_test_saved/"

# %%
results = []

for filename in os.listdir(filepath):
    if filename != '.ipynb_checkpoints':
        results.append(joblib.load(filepath+filename))

# %% [markdown]
# See the last lines of Put_GlueVaR_IS_2_test.ipynb to see how the results are structured.

# %%
np.mean(results,axis=0)
# Out:
# array([7.689885  , 7.69056669])

# %%
np.var(results,axis=0)
# Out:
# array([6.22978469e-05, 6.65788903e-07])

# %%
len(os.listdir(filepath))
# Out:
# 100

# %%
results = np.array(results)

# %%
np.var(results[:,0])/np.var(results[:,1])
# Out:
# 93.56996880494607

# %%
plt.figure(figsize=(6.5,5),dpi=250)
plt.boxplot([results[:,0],results[:,1]],labels=['without IS', 'with IS'])
plt.show()
