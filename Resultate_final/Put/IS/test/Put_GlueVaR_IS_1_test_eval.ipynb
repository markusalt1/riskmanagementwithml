# %%
import joblib
import os
import numpy as np
import matplotlib.pyplot as plt

#folder containing saved results from Put_GlueVaR_IS_1_test.ipynb
filepath = ".../Resultate_final/Put/IS/test/Put_GlueVaR_IS_1_test_saved/"

# %%
results = []

for filename in os.listdir(filepath):
    if filename != '.ipynb_checkpoints':
        results.append(joblib.load(filepath+filename))

# %% [markdown]
# See the last lines of Put_GlueVaR_IS_1_test.ipynb to see how the results are structured.

# %%
np.mean(results,axis=0)
# Out:
# array([7.69089022, 7.69025238])

# %%
np.var(results,axis=0)
# Out:
# array([6.73575775e-05, 2.91604147e-06])

# %%
len(os.listdir(filepath))
# Out:
# 100

# %%
results = np.array(results)

# %%
np.var(results[:,0])/np.var(results[:,1])
# Out:
# 23.098977951121636

# %%
plt.figure(figsize=(6.5,5),dpi=250)
plt.boxplot([results[:,0],results[:,1]],labels=['without IS', 'with IS'])
plt.show()
