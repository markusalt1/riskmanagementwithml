# %%
import joblib
import os
import numpy as np
import matplotlib.pyplot as plt

#folder containing saved results from Put_VaR_ES_IS_1_test.ipynb
filepath = ".../Resultate_final/Put/IS/test/Put_VaR_ES_IS_1_test_saved/"

# %%
results = []

for filename in os.listdir(filepath):
    if filename != '.ipynb_checkpoints':
        results.append(joblib.load(filepath+filename))

# %% [markdown]
# See the last lines of Put_VaR_ES_IS_1_test.ipynb to see how the results are structured.

# %%
np.mean(results,axis=0)
# Out:
# array([8.33478295, 8.33560157, 8.50610982, 8.50745074])

# %%
np.var(results,axis=0)
# Out:
# array([1.75349195e-04, 6.52035994e-07, 1.51187006e-04, 3.14603774e-07])

# %%
len(os.listdir(filepath))
# Out:
# 100

# %%
results = np.array(results)

# %%
np.var(results[:,0])/np.var(results[:,1])
# Out:
# 268.9256366517424

# %%
np.var(results[:,2])/np.var(results[:,3])
# Out:
# 480.5632315609904

# %%
plt.figure(figsize=(6.5,5),dpi=250)
plt.boxplot([results[:,0],results[:,1]],labels=['without IS','with IS'])
plt.show()

# %%
plt.figure(figsize=(6.5,5),dpi=250)
plt.boxplot([results[:,2],results[:,3]],labels=['without IS','with IS'])
plt.show()
