# %%
import joblib
import os
import numpy as np
import matplotlib.pyplot as plt

#folder containing saved results from Put_VaR_ES_IS_2_test.ipynb
filepath = ".../Resultate_final/Put/IS/test/Put_VaR_ES_IS_2_test_saved/"

# %%
results = []

for filename in os.listdir(filepath):
    if filename != '.ipynb_checkpoints':
        results.append(joblib.load(filepath+filename))

# %% [markdown]
# See the last lines of Put_VaR_ES_IS_2_test.ipynb to see how the results are structured.

# %%
np.mean(results,axis=0)
# Out:
# array([8.335501  , 8.33572765, 8.5079424 , 8.50751902])

# %%
np.var(results,axis=0)
# Out:
# array([1.71871027e-04, 2.19364286e-06, 1.61232241e-04, 8.99235836e-07])

# %%
len(os.listdir(filepath))
# Out:
# 100

# %%
results = np.array(results)

# %%
np.var(results[:,0])/np.var(results[:,1])
# Out:
# 78.34959368746581

# %%
np.var(results[:,2])/np.var(results[:,3])
# Out:
# 179.29917182688555

# %%
plt.figure(figsize=(6.5,5),dpi=250)
plt.boxplot([results[:,0],results[:,1]],labels=['without IS','with IS'])
plt.show()

# %%
plt.figure(figsize=(6.5,5),dpi=250)
plt.boxplot([results[:,2],results[:,3]],labels=['without IS','with IS'])
plt.show()
