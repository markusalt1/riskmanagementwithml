# %%
import joblib
import os
import numpy as np
import matplotlib.pyplot as plt

#folder containing saved results from PTF_GlueVaR_IS_1_test.ipynb
filepath = ".../Resultate_final/PTF/IS/IS_test/PTF_GlueVaR_IS_1_test_saved/"

# %%
results = []

for filename in os.listdir(filepath):
    if filename != '.ipynb_checkpoints':
        results.append(joblib.load(filepath+filename))
results = np.array(results)

# %% [markdown]
# See the last lines of PTF_GlueVaR_IS_1_test.ipynb to see how the results are structured.

# %%
np.mean(results,axis=0)
# Out:
# array([107.80511155, 107.80710494])

# %%
np.var(results,axis=0)
# Out:
# array([9.53083550e-04, 2.46991185e-05])

# %%
np.var(results[:,0])/np.var(results[:,1])
# Out:
# 38.58775568346598

# %%
len(os.listdir(filepath))
# Out:
# 100

# %%
results = np.array(results)

# %%
plt.figure(figsize=(6.5,5),dpi=250)
plt.boxplot([results[:,0],results[:,1]],labels=['without IS','with IS'])
plt.show()
