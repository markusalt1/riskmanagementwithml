# %%
import joblib
import os
import numpy as np
import matplotlib.pyplot as plt

#folder containing saved results from PTF_VaR_ES_IS_1_test.ipynb
filepath = ".../Resultate_final/PTF/IS/IS_test/PTF_VaR_ES_IS_1_test_saved/"

# %%
results = []

for filename in os.listdir(filepath):
    if filename != '.ipynb_checkpoints':
        results.append(joblib.load(filepath+filename))
results = np.array(results)

# %% [markdown]
# See the last lines of PTF_VaR_ES_IS_1_test.ipynb to see how the results are structured.

# %%
np.mean(results,axis=0)
# Out:
# array([110.26408025, 110.2612986 , 110.96671002, 110.96330568])

# %%
np.var(results,axis=0)
# Out:
# array([2.48343817e-03, 6.83880988e-05, 2.18961192e-03, 3.23221702e-05])

# %%
np.var(results[:,0])/np.var(results[:,1])
# Out:
# 36.31389403548466

# %%
np.var(results[:,2])/np.var(results[:,3])
# Out:
# 67.74334480886463

# %%
len(os.listdir(filepath))
# Out:
# 101

# %%
results = np.array(results)

# %%
plt.figure(figsize=(6.5,5),dpi=250)
plt.boxplot([results[:,0],results[:,1]],labels=['without IS', 'with IS'])
plt.show()

# %%
plt.figure(figsize=(6.5,5),dpi=250)
plt.boxplot([results[:,2],results[:,3]],labels=['without IS', 'with IS'])
plt.show()
