# %%
import joblib
import os
import numpy as np
import matplotlib.pyplot as plt

#folder containing saved results from PTF_GlueVaR_IS_2_test.ipynb
filepath = ".../Resultate_final/PTF/IS/IS_test/PTF_GlueVaR_IS_2_test_saved/"

# %%
results = []

for filename in os.listdir(filepath):
    if filename != '.ipynb_checkpoints':
        results.append(joblib.load(filepath+filename))
results = np.array(results)

# %% [markdown]
# See the last lines of PTF_GlueVaR_IS_2_test.ipynb to see how the results are structured.

# %%
np.mean(results,axis=0)
# Out:
# array([107.80559813, 107.80658707])

# %%
np.var(results,axis=0)
# Out:
# array([8.01852061e-04, 4.14399267e-05])

# %%
np.var(results[:,0])/np.var(results[:,1])
# Out:
# 19.34974613177509

# %%
len(os.listdir(filepath))
# Out:
# 100

# %%
results = np.array(results)

# %%
plt.figure(figsize=(6.5,5),dpi=250)
plt.boxplot([results[:,0],results[:,1]],labels=['without IS','with IS'])
plt.show()
